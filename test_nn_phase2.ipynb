# %%
#import
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(1)

# %%
#binaryデータを開く関数
def open_grd(gpv_file):
  with open(gpv_file, 'rb') as ifile:
#    data = np.fromfile(ifile, dtype='f4', sep = '')
    data = np.fromfile(ifile, dtype='f8', sep = '')
  return data

# %%
#parameter
#phase = ['uinfdown','uinfup','umax','umin']
phase1 = 'vinfdown'
phase2 = 'vinfup'
#phase3 = 'vmax'
#phase4 = 'vmin'
phase = [phase1,phase2]
num_class = len(phase)
flow = ['400','450','500']
file_num1=6
file_num2=12
nx=191
ny=98
nz=10
file_num = num_class*(file_num1*2+file_num2)
test_size = 0.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#fileの読み込み(位相平均データ)
data_root = '/content/drive/My Drive/機械学習/燃焼振動/velophasemeanfield_calc/'
data_origin = np.zeros((file_num,nz,nx,ny))
phase_num = np.zeros((file_num*nz,num_class))
nf = 0
for ph in phase:
    for fl in flow:
        if fl=='450':
            for n in range(file_num2):
                data_name = 'phasemean_'+ph+'_'+fl+'_'+str(int(n+1))+'.dat'
                file_path = os.path.join(data_root, data_name)
                data_origin[nf,:,:,:] = open_grd(file_path).reshape(nz,nx,ny)
                nnf = nf*10
                for nc in range(num_class):
                  if ph==phase[nc]:
                    phase_num[nnf:nnf+nz,nc] = 1
                    nf += 1
        else:
            for n in range(file_num1):
                data_name = 'phasemean_'+ph+'_'+fl+'_'+str(int(n+1))+'.dat'
                file_path = os.path.join(data_root, data_name)
                data_origin[nf,:,:,:] = open_grd(file_path).reshape(nz,nx,ny)
                nnf = nf*10
                for nc in range(num_class):
                  if ph==phase[nc]:
                    phase_num[nnf:nnf+nz,nc] = 1
                    nf += 1

# %%
#データの切り取りと正規化
data_cut = np.zeros((file_num*nz, ny,nx))
for nn in range(file_num):
    for k in range(nz):
        l = np.max(abs(data_origin[nn,k]))
        for j in range(ny):
            for i in range(nx):
                data_cut[nn*nz+k, ny-1-j, i] = data_origin[nn, k, i, j]/ l

# %%
#データ図示
plt.figure(1, figsize=(10, 16))
plt.subplot(2,1,1)
plt.pcolor(data_cut[0],cmap='jet')
plt.colorbar()
plt.xlim(1, nx)
plt.ylim(1, ny)

plt.subplot(2,1,2)
plt.pcolor(data_cut[file_num*nz-1],cmap='jet')
plt.colorbar()
plt.xlim(1, nx)
plt.ylim(1, ny)

plt.show()

# %%
#target確認
print(phase_num[0])
print(phase_num[100])
print(phase_num[file_num-100])
print(phase_num[file_num])
# Out:
# [1. 0.]
# [1. 0.]
# [0. 1.]
# [1. 0.]

# %%
#データの変形
data_cut = data_cut.reshape(data_cut.shape[0],nx*ny)
print('data_cut shape=',data_cut.shape)
# Out:
# data_cut shape= (480, 18718)

# %%
#学習データとtestデータに分割
from sklearn.model_selection import train_test_split
x_train, x_test,y_train, y_test = train_test_split(data_cut, phase_num, test_size=test_size,random_state=1)
print(x_test.shape)
print(x_train.shape)
# Out:
# (48, 18718)
# (432, 18718)

# %%
#機械学習モデル
from keras.models import Sequential
from keras.layers import Dense, Activation,Dropout
def test_model():
    model=Sequential()
    model.add(Dense(1024,input_shape=(nx*ny,),activation="relu"))
    model.add(Dense(512,activation="relu"))
    model.add(Dense(256,activation="relu"))
    model.add(Dense(128,activation="relu"))
    model.add(Dense(num_class,activation="softmax"))
    return model

# %%
from tensorflow.keras.utils import plot_model
model = test_model()
model.summary()
#plot_model(model, to_file="modelshape_test_cnn_DNS.png",show_shapes=True)
plot_model(model,show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1024)              19168256
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 19,857,538
# Trainable params: 19,857,538
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train model
from keras import optimizers
log_name = "model_cnn_bi_DNS_2.h5"
batch_size = 1
num_epoch = 30

#cp = ModelCheckpoint(log_name, monitor="", verbose=0,
#                     save_best_only=True)

adam = optimizers.Adam(lr=0.0000005)
model.compile(loss="categorical_crossentropy", optimizer=adam,metrics=['accuracy'])

        
history=model.fit(
    x_train , y_train,
    batch_size=batch_size, epochs=num_epoch,
    validation_split=0.1
    #callbacks=[cp]
      )
# Out:
# Epoch 1/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.5110 - accuracy: 0.8505 - val_loss: 0.4101 - val_accuracy: 0.8864
# Epoch 2/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.3567 - accuracy: 0.9381 - val_loss: 0.3130 - val_accuracy: 0.8864
# Epoch 3/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.2843 - accuracy: 0.9459 - val_loss: 0.2583 - val_accuracy: 0.8864
# Epoch 4/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.2439 - accuracy: 0.9485 - val_loss: 0.2223 - val_accuracy: 0.9545
# Epoch 5/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.2222 - accuracy: 0.9433 - val_loss: 0.2075 - val_accuracy: 0.9091
# Epoch 6/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.2048 - accuracy: 0.9536 - val_loss: 0.1871 - val_accuracy: 0.9545
# Epoch 7/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1963 - accuracy: 0.9433 - val_loss: 0.1781 - val_accuracy: 0.9318
# Epoch 8/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1886 - accuracy: 0.9459 - val_loss: 0.1721 - val_accuracy: 0.9318
# Epoch 9/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1828 - accuracy: 0.9485 - val_loss: 0.1730 - val_accuracy: 0.9318
# Epoch 10/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1766 - accuracy: 0.9485 - val_loss: 0.1684 - val_accuracy: 0.9318
# Epoch 11/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1730 - accuracy: 0.9433 - val_loss: 0.1693 - val_accuracy: 0.9091
# Epoch 12/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1681 - accuracy: 0.9510 - val_loss: 0.1601 - val_accuracy: 0.9318
# Epoch 13/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1669 - accuracy: 0.9459 - val_loss: 0.1608 - val_accuracy: 0.9318
# Epoch 14/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1630 - accuracy: 0.9536 - val_loss: 0.1581 - val_accuracy: 0.9318
# Epoch 15/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1551 - accuracy: 0.9510 - val_loss: 0.1601 - val_accuracy: 0.9545
# Epoch 16/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1600 - accuracy: 0.9536 - val_loss: 0.1565 - val_accuracy: 0.9318
# Epoch 17/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1539 - accuracy: 0.9510 - val_loss: 0.1552 - val_accuracy: 0.9318
# Epoch 18/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1539 - accuracy: 0.9459 - val_loss: 0.1632 - val_accuracy: 0.9318
# Epoch 19/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1524 - accuracy: 0.9510 - val_loss: 0.1597 - val_accuracy: 0.9318
# Epoch 20/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1520 - accuracy: 0.9536 - val_loss: 0.1590 - val_accuracy: 0.9318
# Epoch 21/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1477 - accuracy: 0.9562 - val_loss: 0.1543 - val_accuracy: 0.9318
# Epoch 22/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1475 - accuracy: 0.9562 - val_loss: 0.1522 - val_accuracy: 0.9318
# Epoch 23/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1451 - accuracy: 0.9536 - val_loss: 0.1554 - val_accuracy: 0.9318
# Epoch 24/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1423 - accuracy: 0.9588 - val_loss: 0.1563 - val_accuracy: 0.9318
# Epoch 25/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1399 - accuracy: 0.9562 - val_loss: 0.1719 - val_accuracy: 0.9091
# Epoch 26/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1385 - accuracy: 0.9588 - val_loss: 0.1525 - val_accuracy: 0.9318
# Epoch 27/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1370 - accuracy: 0.9562 - val_loss: 0.1606 - val_accuracy: 0.9318
# Epoch 28/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1360 - accuracy: 0.9588 - val_loss: 0.1567 - val_accuracy: 0.9318
# Epoch 29/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1329 - accuracy: 0.9536 - val_loss: 0.1701 - val_accuracy: 0.9091
# Epoch 30/30
# 388/388 [==============================] - 3s 8ms/step - loss: 0.1324 - accuracy: 0.9536 - val_loss: 0.1671 - val_accuracy: 0.9091

# %%
loss     = history.history['loss']
val_loss = history.history['val_loss']
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
nb_epoch = len(loss)

fig=plt.figure(figsize=(12,4))
plt.subplots_adjust(wspace=0.3)
nb_epoch = len(loss)

plt.subplot(1,2,1)
plt.plot(range(1,nb_epoch+1), loss    ,color='k',marker='.', label='loss')
plt.plot(range(1,nb_epoch+1), val_loss    ,color='r',marker='.', label='val_loss')
plt.legend(loc='best', fontsize=12)
plt.xticks(np.arange(1, 30 + 1, 3))
plt.gca().yaxis.set_tick_params(which='both',direction='in')
plt.gca().xaxis.set_tick_params(direction='in')
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('$loss$', fontsize=15)

plt.subplot(1,2,2)
plt.plot(range(1,nb_epoch+1), acc,color='k',marker='.', label='accuracy')
plt.plot(range(1,nb_epoch+1), val_acc,color='r',marker='.', label='val_accuracy')
plt.legend(loc='best', fontsize=12)
plt.xticks(np.arange(1, 30 + 1, 3))
plt.gca().yaxis.set_tick_params(which='both',direction='in')
plt.gca().xaxis.set_tick_params(direction='in')
plt.xlabel('Epoch', fontsize=15)
plt.ylabel('$acc$', fontsize=15)

plt.show()
#fig.savefig("loss_cnn_bi_DNS_2.png")

# %%
#評価
score = model.evaluate(x_test, y_test, verbose = 1)
print('Test loss: ', score[0])
print('Tset accuracy: ', score[1])
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.1676 - accuracy: 0.9583
# Test loss:  0.16762548685073853
# Tset accuracy:  0.9583333134651184
